# %%
https://www.alphavantage.co/documentation/

# %%
# With API Key:

import requests

url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=I8WRUPDX6JPZ48CY'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'IBM', '3. Last Refreshed': '2025-09-04', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2025-09-04': {'1. open': '245.4200', '2. high': '249.2800', '3. low': '242.8500', '4. close': '247.1800', '5. volume': '4765087'}, '2025-09-03': {'1. open': '240.0200', '2. high': '244.2500', '3. low': '239.4100', '4. close': '244.1000', '5. volume': '3156289'}, '2025-09-02': {'1. open': '240.9000', '2. high': '241.5500', '3. low': '238.2500', '4. close': '241.5000', '5. volume': '3469501'}, '2025-08-29': {'1. open': '245.2300', '2. high': '245.4599', '3. low': '241.7200', '4. close': '243.4900', '5. volume': '2967558'}, '2025-08-28': {'1. open': '245.4300', '2. high': '245.8800', '3. low': '243.3600', '4. close': '245.7300', '5. volume': '2820817'}, '2025-08-27': {'1. open': '242.8700', '2. high': '245.9600', '3. low': '242.0000', '4. close': '244.8400', '5. vo
# ...

# %%
# With API Key:

import requests

url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=I8WRUPDX6JPZ48CY'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'IBM', '3. Last Refreshed': '2025-09-04', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2025-09-04': {'1. open': '245.4200', '2. high': '249.2800', '3. low': '242.8500', '4. close': '247.1800', '5. volume': '4765087'}, '2025-09-03': {'1. open': '240.0200', '2. high': '244.2500', '3. low': '239.4100', '4. close': '244.1000', '5. volume': '3156289'}, '2025-09-02': {'1. open': '240.9000', '2. high': '241.5500', '3. low': '238.2500', '4. close': '241.5000', '5. volume': '3469501'}, '2025-08-29': {'1. open': '245.2300', '2. high': '245.4599', '3. low': '241.7200', '4. close': '243.4900', '5. volume': '2967558'}, '2025-08-28': {'1. open': '245.4300', '2. high': '245.8800', '3. low': '243.3600', '4. close': '245.7300', '5. volume': '2820817'}, '2025-08-27': {'1. open': '242.8700', '2. high': '245.9600', '3. low': '242.0000', '4. close': '244.8400', '5. vo
# ...

# %%
import requests
import pandas as pd

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=OCHL&symbol=INFY&interval=weekly&time_period=10&series_type=open&apikey=I8WRUPDX6JPZ48CY'
r = requests.get(url)
data = r.json()
print(data)

df = pd.DataFrame(data)
df.to_csv("output.csv", index=False)

print("CSV file has been created: output.csv")
# Out:
# {'Meta Data': {'1: Symbol': 'INFY', '2: Indicator': 'Exponential Moving Average (EMA)', '3: Last Refreshed': '2025-09-08', '4: Interval': 'weekly', '5: Time Period': 10, '6: Series Type': 'open', '7: Time Zone': 'US/Eastern'}, 'Technical Analysis: EMA': {'2025-09-08': {'EMA': '17.0963'}, '2025-09-05': {'EMA': '17.2044'}, '2025-08-29': {'EMA': '17.3009'}, '2025-08-22': {'EMA': '17.2723'}, '2025-08-15': {'EMA': '17.4750'}, '2025-08-08': {'EMA': '17.8050'}, '2025-08-01': {'EMA': '18.0839'}, '2025-07-25': {'EMA': '18.2536'}, '2025-07-18': {'EMA': '18.2677'}, '2025-07-11': {'EMA': '18.3250'}, '2025-07-03': {'EMA': '18.2061'}, '2025-06-27': {'EMA': '18.1297'}, '2025-06-20': {'EMA': '18.1896'}, '2025-06-13': {'EMA': '18.0696'}, '2025-06-06': {'EMA': '18.0339'}, '2025-05-30': {'EMA': '18.0259'}, '2025-05-23': {'EMA': '18.0238'}, '2025-05-16': {'EMA': '18.0628'}, '2025-05-09': {'EMA': '17.9440'}, '2025-05-02': {'EMA': '18.0223'}, '2025-04-25': {'EMA': '18.2232'}, '2025-04-17': {'EMA': '18.578
# ...

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey=I8WRUPDX6JPZ48CY'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'items': '50', 'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish', 'relevance_score_definition': '0 < x <= 1, with a higher score indicating higher relevance.', 'feed': [{'title': 'Is Alphabet Stock a Buy After the Latest Antitrust Ruling?', 'url': 'https://www.fool.com/investing/2025/09/09/is-alphabet-stock-a-buy-after-the-latest-antitrust/', 'time_published': '20250909T111200', 'authors': ['Robert Izquierdo'], 'summary': 'Legal penalties against Alphabet could affect its AI ambitions.', 'banner_image': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F832117%2Fai-robot-holding-justice-scale_gettyimages-1136269425-1200x800-9b9f185.png&op=resize&w=700', 'source': 'Motley Fool', 'category_within_source': 'n/a', 'source_domain': 'www.fool.com', 'topics': [{'topic': 'Earnings', 'relevance_score': '0.77141'}, {'topic': 'Technology',
# ...

# %%
import requests

url = ('https://newsapi.org/v2/everything?'
       'q=Apple&'
       'from=2025-09-01&'
       'sortBy=popularity&'
       'apiKey=c494f280427646c78473013990b3cd45')

response = requests.get(url)

print(response.json())
# Out:
# {'status': 'ok', 'totalResults': 6316, 'articles': [{'source': {'id': 'wired', 'name': 'Wired'}, 'author': 'Kieran Alger', 'title': 'Do You Need a Satellite Messenger?', 'description': 'Sometimes you need more than a smartphone to stay safe on big adventures.', 'url': 'https://www.wired.com/story/do-you-need-a-satellite-messenger/', 'urlToImage': 'https://media.wired.com/photos/68b5e45ebe1f3bac902742c6/191:100/w_1280,c_limit/Do%20You%20Need%20a%20Satellite%20Messenger.png', 'publishedAt': '2025-09-02T14:00:00Z', 'content': 'On newer Apple iPhones (and Apple Watches,) the Emergency SOS safety net can still connect you to rescue crews even when youre out of cellular service, though its limited to transmitting key informat… [+2922 chars]'}, {'source': {'id': 'wired', 'name': 'Wired'}, 'author': 'Louryn Strampe', 'title': '41 Best Labor Day Sales on WIRED-Tested Gear (2025)', 'description': 'Summer is almost gone, and with it go these great Labor Day deals on WIRED-approved Bluetooth spe
# ...

# %%
import requests
url = ('https://newsapi.org/v2/top-headlines?'
       'country=us&'
       'apiKey=c494f280427646c78473013990b3cd45')
response = requests.get(url)
print(response.json())
# Out:
# {'status': 'ok', 'totalResults': 34, 'articles': [{'source': {'id': 'politico', 'name': 'Politico'}, 'author': 'Kyle Cheney', 'title': 'Judge rules White House ‘pocket rescission’ gambit is illegal - Politico', 'description': 'The Trump administration has appealed the decision.', 'url': 'https://www.politico.com/live-updates/2025/09/04/congress/judge-rules-white-house-pocket-rescission-gambit-is-illegal-00544892', 'urlToImage': 'https://www.politico.com/dims4/default/9d702a1/2147483647/resize/1200x/quality/90/?url=https%3A%2F%2Fstatic.politico.com%2F6e%2F31%2F0947046549b3a93b397d1791981d%2Fu-s-congress-42715.jpg', 'publishedAt': '2025-09-04T19:53:26Z', 'content': None}, {'source': {'id': None, 'name': 'NPR'}, 'author': '', 'title': 'Senators from both parties grilled RFK Jr. on vaccines and more - NPR', 'description': 'In a blistering hearing, Senators from both parties challenged the health secretary to defend his actions, including on vaccines access and CDC leadership.', 'url': 'h
# ...

# %%
import requests
url = ('https://newsapi.org/v2/everything?'
       'sources=bbc-news&'
       'apiKey=c494f280427646c78473013990b3cd45')
response = requests.get(url)
print(response.json())
# Out:
# {'status': 'ok', 'totalResults': 10, 'articles': [{'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': 'RFK Jr defends leadership as lawmakers grill him on vaccines', 'description': "The health secretary clashed with lawmakers as they accused him of restricting Americans' access to vaccines.", 'url': 'https://www.bbc.co.uk/news/articles/cn4l7p771m4o', 'urlToImage': 'https://ichef.bbci.co.uk/ace/branded_news/1200/cpsprodpb/02a2/live/ae55fae0-89bd-11f0-b391-6936825093bd.jpg', 'publishedAt': '2025-09-04T19:52:15.7163416Z', 'content': 'In June, he fired every member of a panel of independent vaccine experts that issues recommendations for immunisations. \r\nPublic health experts raised concerns about the qualifications of the members… [+3413 chars]'}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': 'Boy, 3, pulled from funicular crash that has shocked Portugal', 'description': 'It is unclear what caused the crash in which 16 
# ...

# %%
from newspaper import Article

url = "https://www.bbc.co.uk/news/articles/cn4l7p771m4o"
article = Article(url)
article.download()
article.parse()

print(article.title)
print(article.text)   # full cleaned article text
# Out:
# RFK Jr defends leadership as lawmakers grill him on vaccines
# The vaccine advisory panel was one of several of Kennedy's policy changes that lawmakers brought up during the hearing, leading to clashes.
#
# As Senator Maggie Hassan, a New Hampshire Democrat, accused the health secretary of restricting access to vaccines, Kennedy angrily responded: "You're just making stuff up."
#
# Lawmakers repeatedly questioned Kennedy over his stance on the Covid-19 vaccine, including Senator Mark Warner, a Virginia Democrat, who asked the health leader how many lives the immunisations had saved during the pandemic.
#
# Kennedy said he did not know because of "data chaos" under the Biden administration.
#
# "You've had this job for eight months and you don't know the data about whether vaccines saved lives?" Warner asked.
#
# ...

# %%
import requests
# company = "rambus"
company = "palantir"
url = (f'https://newsapi.org/v2/everything?q=test&to=2025-09-10&from=2025-09-10&apiKey=c494f280427646c78473013990b3cd45')
response = requests.get(url)
print(response.json())
# Out:
# {'status': 'ok', 'totalResults': 219, 'articles': [{'source': {'id': None, 'name': 'Gizmodo.com'}, 'author': 'AJ Dellinger', 'title': 'Dynamic Duo Zuckerberg and Palmer Luckey Reunite for Army Combat Goggles Contract', 'description': 'Just two pals looking to do war crimes together.', 'url': 'https://gizmodo.com/dynamic-duo-zuckerberg-and-palmer-luckey-reunite-for-army-combat-goggles-contract-2000655573', 'urlToImage': 'https://gizmodo.com/app/uploads/2025/05/Mark-Zuckerberg-Palmer-Luckey-1200x675.jpg', 'publishedAt': '2025-09-08T21:20:20Z', 'content': 'Despite spending billions of dollars to make it happen, Meta CEO Mark Zuckerberg and Oculus founder Palmer Luckey were never able to make virtual reality a profitable consumer product. Teamed up agai… [+2370 chars]'}, {'source': {'id': None, 'name': 'MacRumors'}, 'author': 'Hartley Charlton', 'title': 'Apple CEO Tim Cook Invited Back to White House for Tech Event', 'description': 'Apple CEO Tim Cook has been invited to an event for te
# ...

# %%
resp = requests.get('https://newsapi.org/v2/everything?q=apple&to=2025-09-01&from=2025-09-10&apiKey=c494f280427646c78473013990b3cd45', params={"page": 2})
data = resp.json()
data['articles']
# Out:
# [{'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Tim Hardwick',
#   'title': 'Apple Releases New FineWoven MagSafe Wallets and AirTag Key Rings',
#   'description': 'Apple unveiled its new TechWoven cases for iPhone 17 during yesterday\'s "Awe dropping" event, but the company hasn\'t completely abandoned FineWoven. \n\n\n\n\n\nIn fact, the material is still very much part of Apple\'s lineup, with a new collection of FineWoven MagS…',
#   'url': 'https://www.macrumors.com/2025/09/10/apple-finewoven-magsafe-wallets-airtag-key-rings/',
#   'urlToImage': 'https://images.macrumors.com/t/VAd1C6WYRWhT81GNKfjdpNFhDAQ=/1920x/article-new/2025/09/finewoven-wallet-iphone-17.jpg',
#   'publishedAt': '2025-09-10T09:32:13Z',
#   'content': 'Apple unveiled its new TechWoven cases for iPhone 17 during yesterday\'s "Awe dropping" event, but the company hasn\'t completely abandoned FineWoven. \r\nIn fact, the material is still very much part of… [+682 chars]'},
# ...

# %% [markdown]
# ## Main URL NEWS API

# %%
import requests
# company = "rambus"
company = "palantir"
# url = (f'https://newsapi.org/v2/everything?q={company}&language=en&searchIn=title&from=2025-09-01&to=2025-09-08&sortBy=popularity&page=1&apiKey=c494f280427646c78473013990b3cd45')
url = ("https://newsapi.org/v2/everything?q=palantir&language=en&to=2025-09-11&from=2025-09-01&sortBy=publishedAt&apiKey=c494f280427646c78473013990b3cd45")
response = requests.get(url)
print(response.json())



# Stats (2025-09-01 to 2025-09-08):
# Rambus: title: 3 | description: 3 | content: 4
# Palantir: title: 78 | description: 72 | content: 155
# Out:
# {'status': 'ok', 'totalResults': 244, 'articles': [{'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Brian Sozzi', 'title': 'Salesforce CEO Marc Benioff on AI skepticism, its future, and battle with Palantir', 'description': 'Salesforce co-founder and CEO Marc Benioff leaves it all on the field in his latest chat with Yahoo Finance.', 'url': 'https://finance.yahoo.com/news/salesforce-ceo-marc-benioff-on-ai-skepticism-its-future-and-battle-with-palantir-182933004.html', 'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/a1HTJGPhqN5GF4S0dT741Q--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD03OTk-/https://s.yimg.com/os/creatr-uploaded-images/2025-09/d30adb30-8e4f-11f0-afff-0dadb56dcff6', 'publishedAt': '2025-09-10T18:29:33Z', 'content': 'Salesforce (CRM) co-founder and CEO Marc Benioff has a lot on his mind, from growing his AI agent technology to swatting away the naysayers to competing with Palantir (PLTR) for government contracts.… [+2350 chars]'}, {'source': {'id': None, 'name':
# ...

# %%
import json

# Convert response.json() (dict) → JSON string
response_str = json.dumps(response.json(), indent=2)

# Load back into dict
data = json.loads(response_str)

# Extract URLs
urls = [article['url'] for article in data.get('articles', [])]

# Print URLs
for url in urls:
    print(url)
# Out:
# https://finance.yahoo.com/news/salesforce-ceo-marc-benioff-on-ai-skepticism-its-future-and-battle-with-palantir-182933004.html
# https://www.activistpost.com/palantirs-gotham-a-i-surveillance-system-and-peter-thiels-4-part-series-on-the-antichrist/
# https://biztoc.com/x/3e374b756e91f934
# https://biztoc.com/x/5426cf3b05fd7dff
# https://www.eff.org/deeplinks/2025/09/san-francisco-gets-invasive-billionaire-bought-surveillance-hq
# https://finance.yahoo.com/news/whats-going-palantir-stock-wednesday-160354839.html
# https://www.thestreet.com/technology/analysts-revamp-meta-stock-outlook-before-connect-conference-
# https://mergify.com/blog/the-origin-story-of-merge-queues
# https://freerepublic.com/focus/f-chat/4339535/posts
# https://werd.io/using-technology-skills-for-positive-change/
# https://biztoc.com/x/dd7e95944cdfffcb
# https://gizmodo.com/rfk-jrs-hhs-deploys-chatgpt-for-all-staff-2000656557
# http://skift.com/2025/09/10/skift-global-forum-attendees/
# ...

# %% [markdown]
# ## Beautiful Soup

# %%
from bs4 import BeautifulSoup

articles_data = []
# urls = ["https://finance.yahoo.com/news/salesforce-ceo-marc-benioff-on-ai-skepticism-its-future-and-battle-with-palantir-182933004.html", "https://www.activistpost.com/palantirs-gotham-a-i-surveillance-system-and-peter-thiels-4-part-series-on-the-antichrist/",
# "https://biztoc.com/x/3e374b756e91f934",
# "https://biztoc.com/x/5426cf3b05fd7dff",
# "https://www.eff.org/deeplinks/2025/09/san-francisco-gets-invasive-billionaire-bought-surveillance-hq",
# "https://finance.yahoo.com/news/whats-going-palantir-stock-wednesday-160354839.html",
# "https://www.thestreet.com/technology/analysts-revamp-meta-stock-outlook-before-connect-conference-",
# "https://mergify.com/blog/the-origin-story-of-merge-queues",
# "https://freerepublic.com/focus/f-chat/4339535/posts",
# "https://werd.io/using-technology-skills-for-positive-change/"]

for link in urls:
    try:
        res = requests.get(link, timeout=10)
        soup = BeautifulSoup(res.text, 'html.parser')

        # Extract title
        title = soup.title.string.strip() if soup.title else ""

        # Extract all paragraph text
        paragraphs = [p.get_text(strip=True) for p in soup.find_all('p')]
        content = " ".join(paragraphs)

        articles_data.append({
            "url": link,
            "title": title,
            "content": content,
            "content_size": len(content)   # number of characters in content
        })
        print(f"Scraped url({len(content)}): {link}")

    except Exception as e:
        articles_data.append({
            "url": link,
            "title": "",
            "content": f"Error scraping: {e}",
            "content_size": 0
        })

for article in articles_data:
    print(f"{article['url']}: {article['content_size']}")
# Out:
# Scraped url(0): https://finance.yahoo.com/news/salesforce-ceo-marc-benioff-on-ai-skepticism-its-future-and-battle-with-palantir-182933004.html
# Scraped url(1453): https://www.activistpost.com/palantirs-gotham-a-i-surveillance-system-and-peter-thiels-4-part-series-on-the-antichrist/
# Scraped url(287): https://biztoc.com/x/3e374b756e91f934
# Scraped url(285): https://biztoc.com/x/5426cf3b05fd7dff
# Scraped url(7896): https://www.eff.org/deeplinks/2025/09/san-francisco-gets-invasive-billionaire-bought-surveillance-hq
# Scraped url(0): https://finance.yahoo.com/news/whats-going-palantir-stock-wednesday-160354839.html
# Scraped url(43): https://www.thestreet.com/technology/analysts-revamp-meta-stock-outlook-before-connect-conference-
# Scraped url(24527): https://mergify.com/blog/the-origin-story-of-merge-queues
# Scraped url(585343): https://freerepublic.com/focus/f-chat/4339535/posts
# Scraped url(8262): https://werd.io/using-technology-skills-for-positive-change/
# ...

# %%
# Count how many have content_size = 0
zero_count = sum(1 for article in articles_data if article['content_size'] == 0)
total_articles = len(articles_data)

# Total sum of content_size
total_content_size = sum(article['content_size'] for article in articles_data)

print("Articles with content_size = 0:", zero_count)
print("Total content_size across all articles:", total_content_size)
print("Total articles scraped:", total_articles)
# Out:
# Articles with content_size = 0: 17
# Total content_size across all articles: 107783
# Total articles scraped: 78

# %%
# print(articles_data)

# %% [markdown]
# ## Scrapy Library

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

# urls = [
#     "https://example.com",
#     "https://www.wikipedia.org"
# ]

class ArticleSpider(scrapy.Spider):
    name = "article_spider"
    start_urls = urls

    def parse(self, response):
        title = response.css("title::text").get(default="").strip()
        content = " ".join(p.get().strip() for p in response.css("p::text"))
        yield {
            "url": response.url,
            "title": title,
            "content": content,
            "content_size": len(content),
        }

process = CrawlerProcess(settings={
    "LOG_LEVEL": "ERROR",   # keep output clean
})
results = []
process.crawl(ArticleSpider)
process.start()

# Collect results from items
for spider in process.crawlers:
    results.extend(spider.spider.crawler.stats.get_stats().get("item_scraped_count", []))

print(results)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[38], line 28
#      26 results = []
#      27 process.crawl(ArticleSpider)
# ---> 28 process.start()
#      30 # Collect results from items
#      31 for spider in process.crawlers:
#
# File g:\Signal-Extraction\src\env\Lib\site-packages\scrapy\crawler.py:502, in CrawlerProcess.start(self, stop_after_crawl, install_signal_handlers)
#     498 if install_signal_handlers:
#     499     reactor.addSystemEventTrigger(
#     500         "after", "startup", install_shutdown_handlers, self._signal_shutdown
#     501     )
# --> 502 reactor.run(installSignalHandlers=install_signal_handlers)
#
# File g:\Signal-Extraction\src\env\Lib\site-packages\twisted\internet\asyncioreactor.py:253, in AsyncioSelectorReactor.run(self, installSignalHandlers)
#     251 def run(self, installSignalHandlers=True):
# ...

# %% [markdown]
# ## Selenium

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time

# List of article URLs
# urls = [
#     "https://finance.yahoo.com/news/evercore-picks-astera-macom-top-150433255.html",
#     "https://www.etfdailynews.com/2025/09/07/trexquant-investment-lp-sells-75897-shares-of-rambus-inc-rmbs/",
#     "https://www.etfdailynews.com/2025/09/05/rambus-inc-rmbs-shares-sold-by-alphaquest-llc/",
#     "https://biztoc.com/x/81a6ba9d5a3bd19c"
# ]

# Setup Chrome options for headless browsing
chrome_options = Options()
chrome_options.add_argument("--headless")  # run in background
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--window-size=1920,1080")

# Initialize driver
service = Service("chromedriver.exe")  # path to your chromedriver
driver = webdriver.Chrome(service=service, options=chrome_options)

# Store scraped articles
articles_data = []

for link in urls:
    try:
        driver.get(link)
        time.sleep(3)  # wait for JS to render

        # Get title
        title = driver.title

        # Get all paragraph texts
        paragraphs = driver.find_elements(By.TAG_NAME, "p")
        content = " ".join([p.text for p in paragraphs])

        articles_data.append({
            "url": link,
            "title": title,
            "content": content,
            "content_size": len(content)
        })

    except Exception as e:
        articles_data.append({
            "url": link,
            "title": "",
            "content": f"Error scraping: {e}",
            "content_size": 0
        })

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File g:\Signal-Extraction\src\env\Lib\site-packages\selenium\webdriver\common\driver_finder.py:64, in DriverFinder._binary_paths(self)
#      63 if not Path(path).is_file():
# ---> 64     raise ValueError(f"The path is not a valid file: {path}")
#      65 self._paths["driver_path"] = path
#
# ValueError: The path is not a valid file: chromedriver.exe
#
# The above exception was the direct cause of the following exception:
#
# NoSuchDriverException                     Traceback (most recent call last)
# Cell In[1], line 24
#      22 # Initialize driver
#      23 service = Service("chromedriver.exe")  # path to your chromedriver
# ---> 24 driver = webdriver.Chrome(service=service, options=chrome_options)
#      26 # Store scraped articles
#      27 articles_data = []
#
# ...

# %% [markdown]
# ## Playwright

# %%
import asyncio
from playwright.async_api import async_playwright

# urls = [
#     "https://finance.yahoo.com/news/evercore-picks-astera-macom-top-150433255.html",
#     "https://www.etfdailynews.com/2025/09/07/trexquant-investment-lp-sells-75897-shares-of-rambus-inc-rmbs/",
#     "https://www.etfdailynews.com/2025/09/05/rambus-inc-rmbs-shares-sold-by-alphaquest-llc/",
#     "https://biztoc.com/x/81a6ba9d5a3bd19c"
# ]

articles_data = []

async def scrape_articles():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        for link in urls:
            try:
                await page.goto(link, timeout=15000)
                await page.wait_for_load_state("domcontentloaded")

                # Get title
                title = await page.title()

                # Get all paragraphs
                paragraphs = await page.query_selector_all("p")
                content = " ".join([await p.inner_text() for p in paragraphs])

                articles_data.append({
                    "url": link,
                    "title": title,
                    "content": content,
                    "content_size": len(content)
                })

            except Exception as e:
                articles_data.append({
                    "url": link,
                    "title": "",
                    "content": f"Error scraping: {e}",
                    "content_size": 0
                })

        await browser.close()

# Run the async function in Jupyter
await scrape_articles()

# Print URL and content_size
for article in articles_data:
    print(f"{article['url']}: {article['content_size']}")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[3], line 48
#      45         await browser.close()
#      47 # Run the async function in Jupyter
# ---> 48 await scrape_articles()
#      50 # Print URL and content_size
#      51 for article in articles_data:
#
# Cell In[3], line 14, in scrape_articles()
#      13 async def scrape_articles():
# ---> 14     async with async_playwright() as p:
#      15         browser = await p.chromium.launch(headless=True)
#      16         page = await browser.new_page()
#
# File g:\Signal-Extraction\src\env\Lib\site-packages\playwright\async_api\_context_manager.py:46, in PlaywrightContextManager.__aenter__(self)
#      44 if not playwright_future.done():
#      45     playwright_future.cancel()
# ---> 46 playwright = AsyncPlaywright(next(iter(done)).result())
#      47 playwright.stop = self.__aexit__  # type: ignore
# ...
