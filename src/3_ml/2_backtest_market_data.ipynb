# %% [markdown]
# ## Backtest Market Data

# %% [markdown]
# Prompt:
#
# Based on the given set of columns created after the ml price prediction step.
# Create a backtest code, that backtests and gives the profit per unit of share, say from the first buy signal until the first sell signal, where the purchase unit is sold and a new short position is openend.
